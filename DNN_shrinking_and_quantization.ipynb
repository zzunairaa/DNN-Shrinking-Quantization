# %% [markdown]
# # **LAB03 APAI DNN shrinking & quantization**
#
# **Credits**: *Francesco Conti, Ilenia Carboni, Davide Nadalini, Lorenzo Lamberti, Luca Bompani, Alberto Dequino*.
# *(University of Bologna)*
#
# **Contacts**: d.nadalini@unibo.it, ilenia.carboni4@unibo.it, f.conti@unibo.it

# %% [markdown]
# ## **In this Hands-on session:**
#
# A first-time user of Pytorch framework will learn how to quantize a CNN and how to visualize its graph

# %% [markdown]
# ### Tasks:
#
# ---
#
# 1. Load a model’s pretrained weights;
# 2. Reduce network’s size under 5MMAC;
# 3. Re-train the reduced network and verify network’s accuracy;
# 4. Fake-quantize with Brevitas;
# 5. True-quantize with DeepQuant, export ONNX and analyze the float32 and true-quantized models with Netron.
#
# ---

# %% [markdown]
# ## **Let's start !**

# %% [markdown]
# ## ⚠️⚠️Setup (ONLY ONCE)⚠️⚠️:
# You need to run the following cells.
#
# 1.   Setup torch, specific version for cpu (you don't need a GPU to run this lab, each network takes ~7min to run)
# 2.   Install missing dependencies (colab itself may ask you to restart your session, do it)
# 3. Install DeepQuant (it takes a bit of time).
#
# After DeepQuant is successfully installed, RESTART YOUR SESSION (and don't delete your data unless you want to re-do the whole process)

# %% [markdown]
# We first need to setup the environment to a lower PyTorch version. We will setup PyTorch with no CUDA support. Don't worry, the neural networks won't take more than 7 mins to train!

# %%
# !pip uninstall -y torch torchvision torchaudio sympy
# CPU-only PyTorch (torch.fx + DeepQuant compatible)
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --extra-index-url https://download.pytorch.org/whl/cpu
# SymPy compatible with torch.fx
# !pip install sympy==1.11
# Out:
# Found existing installation: torch 2.4.0+cpu
# Uninstalling torch-2.4.0+cpu:
#   Successfully uninstalled torch-2.4.0+cpu
# Found existing installation: torchvision 0.19.0+cpu
# Uninstalling torchvision-0.19.0+cpu:
#   Successfully uninstalled torchvision-0.19.0+cpu
# Found existing installation: torchaudio 2.4.0+cpu
# Uninstalling torchaudio-2.4.0+cpu:
#   Successfully uninstalled torchaudio-2.4.0+cpu
# Found existing installation: sympy 1.11
# Uninstalling sympy-1.11:
#   Successfully uninstalled sympy-1.11
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Collecting torch==2.4.0
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.4.0%2Bcpu-cp312-cp312-linux_x86_64.whl (195.0 MB)
# Collecting torchvision==0.19.0
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.19.0%2Bcpu-cp312-cp312-linux_x86_64.whl (1.6 MB)
# Collecting torchaudio==2.4.0
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.4.0%2Bcpu-cp312-cp312-linux_x86_64.whl (1.7 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (4.15.0)
# Collecting sympy (from torch==2.4.0)
#   Using cached https://download.pytorch.org/whl/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (2025.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.4.0) (69.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.19.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.19.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.4.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.4.0) (1.3.0)
# Using cached https://download.pytorch.org/whl/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: sympy, torch, torchvision, torchaudio
# Successfully installed sympy-1.14.0 torch-2.4.0+cpu torchaudio-2.4.0+cpu torchvision-0.19.0+cpu
# Collecting sympy==1.11
#   Using cached sympy-1.11-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy==1.11) (1.3.0)
# Using cached sympy-1.11-py3-none-any.whl (6.5 MB)
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
# Successfully installed sympy-1.11

# %% [markdown]
# We additionally need to ensure some libraries are present (mainly brevitas, more on that later). At this stage, it will prompt you to restart runtime. Do not worry. It is expected. Re-run this cell so you finish setup.

# %%
# !pip install tqdm
# !pip install scikit-learn
# !pip install brevitas
# !pip install torchinfo
# !pip install onnxscript
# !pip install sympy==1.11
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: brevitas in /usr/local/lib/python3.12/dist-packages (0.12.1)
# Requirement already satisfied: dependencies==2.0.1 in /usr/local/lib/python3.12/dist-packages (from brevitas) (2.0.1)
# Requirement already satisfied: numpy<=1.26.4 in /usr/local/lib/python3.12/dist-packages (from brevitas) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from brevitas) (25.0)
# Requirement already satisfied: setuptools<70.0 in /usr/local/lib/python3.12/dist-packages (from brevitas) (69.5.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from brevitas) (1.11)
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.12/dist-packages (from brevitas) (2.4.0+cpu)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from brevitas) (4.15.0)
# Requirement already satisfied: unfoldNd in /usr/local/lib/python3.12/dist-packages (from brevitas) (0.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->brevitas) (3.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->brevitas) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->brevitas) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.12->brevitas) (2025.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy->brevitas) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.12->brevitas) (3.0.3)
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: onnxscript in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.26.4)
# Requirement already satisfied: onnx_ir<2,>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (0.1.11)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (1.19.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (25.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from onnxscript) (4.15.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.16->onnxscript) (5.29.5)
# Requirement already satisfied: sympy==1.11 in /usr/local/lib/python3.12/dist-packages (1.11)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy==1.11) (1.3.0)

# %% [markdown]
# Now, DeepQuant will take a bit of time. Do not worry.

# %%
# !rm -rf DeepQuant/

# %%
# !git clone --branch unitn25-exercise --single-branch https://github.com/FrancescoConti/DeepQuant.git
# %cd DeepQuant
# !git submodule update --init --recursive
# !pip install -e .
# Out:
# Cloning into 'DeepQuant'...
# remote: Enumerating objects: 209, done.
# remote: Counting objects: 100% (63/63), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 209 (delta 33), reused 17 (delta 17), pack-reused 146 (from 1)
# Receiving objects: 100% (209/209), 22.86 MiB | 12.89 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/DeepQuant
# Obtaining file:///content/DeepQuant
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (2.4.0+cpu)
# Requirement already satisfied: torchvision>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (0.19.0+cpu)
# Requirement already satisfied: torchaudio>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (2.4.0+cpu)
# Requirement already satisfied: brevitas>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (0.12.1)
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (1.8.2)
# Requirement already satisfied: black in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (25.9.0)
# Requirement already satisfied: isort in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (7.0.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (8.4.2)
# Requirement already satisfied: netron in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (8.7.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (4.67.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (0.4.6)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (1.19.1)
# Requirement already satisfied: onnxoptimizer in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (0.3.13)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (1.23.1)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (from DeepQuant==0.1.0) (8.3.217)
# Requirement already satisfied: dependencies==2.0.1 in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (2.0.1)
# Requirement already satisfied: numpy<=1.26.4 in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (25.0)
# Requirement already satisfied: setuptools<70.0 in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (69.5.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (1.11)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (4.15.0)
# Requirement already satisfied: unfoldNd in /usr/local/lib/python3.12/dist-packages (from brevitas>=0.11.0->DeepQuant==0.1.0) (0.2.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->DeepQuant==0.1.0) (3.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->DeepQuant==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->DeepQuant==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.1.2->DeepQuant==0.1.0) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.16.2->DeepQuant==0.1.0) (11.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from black->DeepQuant==0.1.0) (8.3.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black->DeepQuant==0.1.0) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from black->DeepQuant==0.1.0) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black->DeepQuant==0.1.0) (4.5.0)
# Requirement already satisfied: pytokens>=0.1.10 in /usr/local/lib/python3.12/dist-packages (from black->DeepQuant==0.1.0) (0.2.0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->DeepQuant==0.1.0) (5.29.5)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->DeepQuant==0.1.0) (0.5.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime->DeepQuant==0.1.0) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime->DeepQuant==0.1.0) (25.9.23)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->DeepQuant==0.1.0) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->DeepQuant==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->DeepQuant==0.1.0) (2.19.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics->DeepQuant==0.1.0) (0.15.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (4.11.0.86)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (1.16.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->DeepQuant==0.1.0) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->DeepQuant==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->DeepQuant==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->DeepQuant==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->DeepQuant==0.1.0) (2025.10.5)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime->DeepQuant==0.1.0) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1.2->DeepQuant==0.1.0) (3.0.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy->brevitas>=0.11.0->DeepQuant==0.1.0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->DeepQuant==0.1.0) (1.17.0)
# Building wheels for collected packages: DeepQuant
#   Building editable for DeepQuant (pyproject.toml) ... done
#   Created wheel for DeepQuant: filename=deepquant-0.1.0-0.editable-py3-none-any.whl size=7078 sha256=ca241cd4e0a6a55ea3918878a8eab1799d43b41de8eb814768188c6b44931286
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k5_rlypl/wheels/af/7b/5b/a7e795255fc50b248deab17e835ed860b55ffe86c76b34f3e7
# Successfully built DeepQuant
# Installing collected packages: DeepQuant
#   Attempting uninstall: DeepQuant
#     Found existing installation: DeepQuant 0.1.0
#     Uninstalling DeepQuant-0.1.0:
#       Successfully uninstalled DeepQuant-0.1.0
# Successfully installed DeepQuant-0.1.0

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# ⚠️**Restart your runtime**. Ensure you don't delete your data.

# %% [markdown]
# ### From now on, don't run the previous cells. Let's move to the lab

# %% [markdown]
# We import most of the packages we need

# %%
#basic
import os
from os.path import join
import numpy as np
from tqdm import tqdm
import time

#plotting
import matplotlib.pyplot as plt

#torch
import torch; print('\nPyTorch version in use:', torch.__version__, '\ncuda avail: ', torch.cuda.is_available())
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

#torchvision
import torchvision
from torchvision import transforms, datasets

# others
from copy import deepcopy
from tqdm.autonotebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import inspect
from collections import defaultdict

# Brevitas
from typing import Union, Tuple, List, Dict
import brevitas.nn as qnn
from brevitas.graph.equalize import activation_equalization_mode
# Out:
# PyTorch version in use: 2.4.0+cpu
# cuda avail:  False

# %% [markdown]
# ## Set device
# Between "cuda" and "cpu". You only have "cpu" available, by design.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device: %s' % device)
# Out:
# Device: cpu

# %% [markdown]
# # **Recap from LAB2: how to train a neural network**
# This section recaps the previous LAB2. Take this as a chance to go over it again if something is not clear!

# %% [markdown]
# ## Creating a Model
# ---

# %% [markdown]
# Let's go back to our network from LAB2:

# %%
class ConvBnRelu(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(ConvBnRelu, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=stride, padding=1, bias=False, padding_mode='zeros')
        self.bn1 = nn.BatchNorm2d(num_features=out_channels, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.relu1 = nn.ReLU()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        return x

class CNN(nn.Module):
    def __init__(self, n_classes=10, depth_mult=1.):
        super(CNN, self).__init__()
        # first_conv_channels=int(32*depth_mult)
        self.ConvBnRelu1 = ConvBnRelu(1, 32,  stride=1) # conv3x3: ch_in=1, ch_out=32, in=28x28, out=28x28/2
        self.ConvBnRelu2 = ConvBnRelu(32, 64,  stride=1) # conv3x3: ch_in=1, ch_out=32, in=28x28, out=28x28/2
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, return_indices=False, ceil_mode=False) # MaxPool2: in=14x14, out=14x14/2
        self.ConvBnRelu3 = ConvBnRelu(64, 128, stride=2) # conv3x3: ch_in=32, ch_out=64, in=7x7, out=7x7
        self.dropout = nn.Dropout(p=0.5, inplace=False)
        fc_in_size = 7*7*128
        self.fc = nn.Linear(fc_in_size, n_classes, bias=False)
        # self.softmax = nn.LogSoftmax(dim=1) # we remove it because the quantization tool (Quantlab) does not handle it

    def forward(self, x):
        x = self.ConvBnRelu1(x)
        x = self.ConvBnRelu2(x)
        x = self.pool(x)
        x = self.ConvBnRelu3(x)
        x = self.dropout(x)
        x = x.flatten(1)
        output = self.fc(x)
        # output = self.softmax(x)
        return output

net = CNN().to(device)

# %% [markdown]
# ![NN2 (2).png](data:image/png;base64,...)

# %%
#@title Dummy input  { form-width: "70%" }
# input_size = (batch_n, img_ch,img_width, img_height)
input_size = (1, 1, 28, 28)  #@param
input = torch.randn(input_size).to(device)

# %% [markdown]
# ## Count network's parameters and MAC operations
#
# ---
#
# A useful function to measure the model's MAC operations and number of parameters.
#
# **TorchInfo insights:**
# This tool calculates the Parameters Size as (number_of_parameters*4).
# This because each parameter needs 4 Bytes (32bit) to be represented in float32 format.

# %%
def print_summary(net, input_size, verbose=True):
    from torchinfo import summary
    net_info = summary(net, input_size=input_size)
    params = net_info.total_params
    macs = net_info.total_mult_adds
    if verbose: print(net_info)
    return params, macs

# calculate n° parameters and mac operations
params, macs = print_summary(deepcopy(net), input_size) #use deepcopy to avoid graph modifications by hese function calls
# print them
print("\nNetwork's \tn°params: %.3fk \tMAC: %.3fM\n" % (params/1e3, macs/1e6))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN                                      [1, 10]                   --
# ├─ConvBnRelu: 1-1                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-1                       [1, 32, 28, 28]           288
# │    └─BatchNorm2d: 2-2                  [1, 32, 28, 28]           64
# │    └─ReLU: 2-3                         [1, 32, 28, 28]           --
# ├─ConvBnRelu: 1-2                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-4                       [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-5                  [1, 64, 28, 28]           128
# │    └─ReLU: 2-6                         [1, 64, 28, 28]           --
# ├─MaxPool2d: 1-3                         [1, 64, 14, 14]           --
# ├─ConvBnRelu: 1-4                        [1, 128, 7, 7]            --
# │    └─Conv2d: 2-7                       [1, 128, 7, 7]            73,728
# │    └─BatchNorm2d: 2-8                  [1, 128, 7, 7]            256
# │    └─ReLU: 2-9                         [1, 128, 7, 7]            --
# ├─Dropout: 1-5                           [1, 128, 7, 7]            --
# ├─Linear: 1-6                            [1, 10]                   62,720
# ==========================================================================================
# Total params: 155,616
# Trainable params: 155,616
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 18.35
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.30
# Params size (MB): 0.62
# Estimated Total Size (MB): 1.93
# ==========================================================================================
#
# Network's 	n°params: 155.616k 	MAC: 18.352M

# %% [markdown]
# ## Dataset & DataLoaders
#
# ---
#
# We use the [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist), which is a set of 28x28 grayscale images of clothes.

# %%
def get_data_loaders(train_batch_size=128, val_batch_size=128, path='./data/fashionmnist',verbose=False):
    # 1. define data transformations
    fashion_mnist = datasets.FashionMNIST(download=True, train=True, root=path).train_data.float()
    data_transform = transforms.Compose([transforms.ToTensor(),
                                         transforms.Normalize((fashion_mnist.mean()/255,), (fashion_mnist.std()/255,))])

    # 2. Load train/valid datasets
    train_dataset = datasets.FashionMNIST(download=False, root=path, transform=data_transform, train=True)
    valid_dataset = datasets.FashionMNIST(download=False, root=path, transform=data_transform, train=False)

    # 3. define dataloaders
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=train_batch_size,
        shuffle=True)
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset,
        batch_size=val_batch_size,
        shuffle=False)

    # Optional: count how many images we have in each set
    train_dataset_size = len(train_dataset)
    valid_dataset_size = len(valid_dataset)
    if verbose: print('Dataset size:\nTraining images %d,\nValidation images %d' % (train_dataset_size, valid_dataset_size))

    return train_loader, valid_loader

train_loader, val_loader = get_data_loaders(verbose=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py:76: UserWarning: train_data has been renamed data
#   warnings.warn("train_data has been renamed data")
# Dataset size:
# Training images 60000,
# Validation images 10000

# %% [markdown]
# ## Testing the CNN over the dataset
#
# ---

# %% [markdown]
# ### Accuracy Metric calculation

# %% [markdown]
# First we define a function to calculate the accuracy, defined as: `accuracy = num_correct_predictions/total_n_predictions`

# %%
def calculate_accuracy(best_guesses, targets):
    num_correct = torch.eq(targets, best_guesses).sum().item()
    total_guesses = len(targets)
    correct_percentage = num_correct/total_guesses
    return correct_percentage

# %% [markdown]
# ### Testing Function
# The following cell defines a function, `validate,` that runs a network on a dataset and shows the percentage of the dataset that was correctly classified.

# %%
from brevitas.export.inference import quant_inference_mode

def validate(net, val_loader, loss_function, accuracy_score):
    val_losses = []
    val_accuracy = []

    # set net to evaluating (testing)
    net.eval()
    with torch.no_grad(), quant_inference_mode(net):
        for batch_idx, data in tqdm(enumerate(val_loader), total=len(val_loader)):
            inputs, labels = data[0].to(device), data[1].to(device)

            # net forward
            outputs = net(inputs) # this gets the prediction from the network

            # calculate loss
            loss = loss_function(outputs, labels)
            val_losses.append(loss) # append current average training loss to a buffer variable, for plotting learning curve

            # calculate validation accuracy
            predicted_classes = torch.max(outputs, 1)[1] # get class from network's prediction
            val_accuracy.append(calculate_accuracy(predicted_classes.cpu(), labels.cpu()))

    average_val_loss = sum(val_losses)/(batch_idx+1)
    average_val_accuracy = sum(val_accuracy)/len(val_loader)
    return average_val_accuracy, average_val_loss

# %% [markdown]
# ## Training Loop

# %%
# Move net to gpu:
net.to(device)

# Define loss function
loss_function = nn.CrossEntropyLoss() # cross entropy works well for multi-class problems


def training(net, train_loader, val_loader, loss_function, epochs, lr=3e-4):
    # Define optimizer
    optimizer = torch.optim.Adam(net.parameters(), lr=lr)

    # count tot batches
    tot_train_batches = len(train_loader)
    tot_val_batches = len(val_loader)

    # Create lists to store training history
    train_loss_history = []
    train_accuracy_history = []
    # Create lists to store validation history
    val_loss_history = []
    val_accuracy_history = []

    start_ts = time.time()
    # loop for every epoch (training + evaluation)
    for epoch in range(epochs):
        total_epoch_loss = 0
        train_accuracy = []

        # progress bar (works in Jupyter notebook too!)
        progress = tqdm(enumerate(train_loader), desc="Loss: ", total=tot_train_batches)

        # ----------------- TRAINING  -------------------- #
        # set model to training
        net.train()

        for batch_idx, data in progress:
            inputs, labels = data[0].to(device), data[1].to(device)

            # Compute prediction (forward input in the model)
            outputs = net(inputs)
            # Compute prediction error with the loss function
            loss = loss_function(outputs, labels)
            # Backpropagation
            net.zero_grad()
            loss.backward()
            # Optimizer step
            optimizer.step()

            # getting training quality data
            current_loss = loss.item()

            #compute average loss
            total_epoch_loss += current_loss
            average_train_loss = total_epoch_loss/(batch_idx+1)

            # calculate training accuracy
            predicted_classes = torch.max(outputs, 1)[1] # get class from network's prediction
            train_accuracy.append(calculate_accuracy(predicted_classes.cpu(), labels.cpu()))
            average_train_accuracy = sum(train_accuracy)/(batch_idx+1)

            # updating progress bar
            progress.set_description("Training Loss: {:.4f}, Accuracy: {:.4f}".format(average_train_loss, average_train_accuracy))

            ## DEBUG: stop after one single batch
            # break

        # ----------------- VALIDATION  ----------------- #
        average_val_accuracy, average_val_loss = validate(net, val_loader, loss_function, accuracy_score)

        # compute mean accuracy
        average_train_accuracy = sum(train_accuracy)/tot_train_batches

        # print training/validation Accuracy and Loss
        print('Epoch %d/%d' % (epoch+1,epochs), 'Training loss:  %.4f' % (average_train_loss), 'Accuracy: %.4f' % (average_train_accuracy))
        print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))

        # append current average training loss to a buffer variable, for plotting learning curve later
        train_loss_history.append(average_train_loss)
        val_loss_history.append(average_val_loss)
        train_accuracy_history.append(average_train_accuracy)
        val_accuracy_history.append(average_val_accuracy)

    print('Training time: %.1f seconds' % (time.time()-start_ts))


    return train_loss_history, train_accuracy_history, val_loss_history, val_accuracy_history

# retrain the network
epochs = 2
_, _, _, _= training(net, train_loader, val_loader, loss_function, epochs)
# Out:
# Loss:   0%|          | 0/469 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 1/2 Training loss:  0.3027 Accuracy: 0.8914
# Validation Loss: 0.2867 Accuracy: 0.8959
# Loss:   0%|          | 0/469 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 2/2 Training loss:  0.2605 Accuracy: 0.9061
# Validation Loss: 0.2610 Accuracy: 0.9048
# Training time: 356.3 seconds

# %% [markdown]
# ## Save/Load the CNN weights

# %%
#@title Training parameters { form-width: "70%" }
model_export_path = "./model/" #@param {type:"string"}
model_name = 'ExampleNetzizou.pth' #@param {type:"string"}
os.makedirs(model_export_path, exist_ok=True)

# %%
def save_net(net,model_path, model_name):
    #Save Pytorch model
    torch.save(net.state_dict(), join(model_path,model_name))

save_net(net,model_export_path, model_name)

# %%
def load_net(net, model_path, model_name, device):
    ''' Load a PyTorch Model '''
    checkpoint_file= join(model_path,model_name)
    # load weights file
    state_dict = torch.load(checkpoint_file, map_location=device)
    # Load weights into the network
    net.load_state_dict(state_dict)
    # to device (cpu or gpu)
    net = CNN().to(device)
    return net

# %% [markdown]
# # **This concludes the recap. Let's now move to the tasks!**

# %% [markdown]
# # **TASK1:** Load Pre-Trained Model
#
# ---

# %% [markdown]
# Now, reload the pre-trained network. It should train quick enough to use your own weights, but we will give you a ExampleNet.pth if you're having issues. Clone the lab repository!

# %%
# !rm -r APAI25-LAB03-DNN-Shrinking-and-Quantization
# !git clone https://github.com/EEESlab/APAI25-LAB03-DNN-Shrinking-and-Quantization
# Out:
# Cloning into 'APAI25-LAB03-DNN-Shrinking-and-Quantization'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 23 (delta 7), reused 18 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 6.26 MiB | 14.44 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
#@title Define path for CNN's pre-trained weights { form-width: "70%" }
# pre_trained_path = "./APAI24-LAB03-DNN-Shrinking-and-Quantization/" #@param {type:"string"}
pre_trained_path = "./APAI25-LAB03-DNN-Shrinking-and-Quantization" #@param {type:"string"}
model_name = 'ExampleNetzizou.pth' #@param {type:"string"}

# %% [markdown]
# ### Load pre-trained weights

# %%
load_net(CNN().to(device), model_export_path, model_name, device)
params, macs = print_summary(deepcopy(net), input_size)
print("\nNetwork's \tn°params: %.3fk \tMAC: %.3fM\n" % (params/1e3, macs/1e6))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN                                      [1, 10]                   --
# ├─ConvBnRelu: 1-1                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-1                       [1, 32, 28, 28]           288
# │    └─BatchNorm2d: 2-2                  [1, 32, 28, 28]           64
# │    └─ReLU: 2-3                         [1, 32, 28, 28]           --
# ├─ConvBnRelu: 1-2                        [1, 64, 28, 28]           --
# │    └─Conv2d: 2-4                       [1, 64, 28, 28]           18,432
# │    └─BatchNorm2d: 2-5                  [1, 64, 28, 28]           128
# │    └─ReLU: 2-6                         [1, 64, 28, 28]           --
# ├─MaxPool2d: 1-3                         [1, 64, 14, 14]           --
# ├─ConvBnRelu: 1-4                        [1, 128, 7, 7]            --
# │    └─Conv2d: 2-7                       [1, 128, 7, 7]            73,728
# │    └─BatchNorm2d: 2-8                  [1, 128, 7, 7]            256
# │    └─ReLU: 2-9                         [1, 128, 7, 7]            --
# ├─Dropout: 1-5                           [1, 128, 7, 7]            --
# ├─Linear: 1-6                            [1, 10]                   62,720
# ==========================================================================================
# Total params: 155,616
# Trainable params: 155,616
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 18.35
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.30
# Params size (MB): 0.62
# Estimated Total Size (MB): 1.93
# ==========================================================================================
#
# Network's 	n°params: 155.616k 	MAC: 18.352M
# /tmp/ipython-input-2733931076.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(checkpoint_file, map_location=device)

# %% [markdown]
# Test again the network accuracy, to be sure that you saved/loaded weights correctly.

# %%
# Test over validation dataset
loss_function=nn.CrossEntropyLoss()
average_val_accuracy, average_val_loss = validate(net, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 0.2610 Accuracy: 0.9048

# %% [markdown]
# **if accuracy ~ 90% : you were successful !!**

# %% [markdown]
# # **TASK2:** Reduce Network's MAC operations

# %% [markdown]
# ---
#
# Current network has:
# *   n°params: 155.616k
# *   MAC: 18.3M
#
# **Task:** Reduce it below 5 MMAC, but keeping accuracy similar to the starting one.
#
# ---
#
# There are different approaches. The first one is the one needed to complete the lab.
# 1. Reduce the number of channels of the convolutional layers (halve them). **This is the intended approach**
#
# You can explore another two ways:
#
# 2. Add or remove layers
# 3. Play with the "stride" of the convolutional layers

# %% [markdown]
# ## New network with reduced size

# %%
class ConvBnRelu(nn.Module):
    def __init__(self, in_channels, out_channels, stride):
        super(ConvBnRelu, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, stride=stride, padding=1, bias=False, padding_mode='zeros')
        self.bn1 = nn.BatchNorm2d(num_features=out_channels, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
        self.relu1 = nn.ReLU()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        return x

class CNN_reduced(nn.Module):

    def __init__(self, n_classes=10):
        super(CNN_reduced, self).__init__()
        # Original Channels: (1, 32) -> (32, 64) -> (64, 128)
        # Halved Channels:   (1, 16) -> (16, 32) -> (32, 64)

        # ConvBnRelu1: Output channels halved from 32 to 16
        self.ConvBnRelu1 = ConvBnRelu(1, 16,  stride=1)
        # ConvBnRelu2: Input (from 32 -> 16), Output (from 64 -> 32)
        self.ConvBnRelu2 = ConvBnRelu(16, 32,  stride=1)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, return_indices=False, ceil_mode=False) # MaxPool2: in=14x14, out=14x14/2
        # ConvBnRelu3: Input (from 64 -> 32), Output (from 128 -> 64)
        self.ConvBnRelu3 = ConvBnRelu(32, 64, stride=2)

        self.dropout = nn.Dropout(p=0.5, inplace=False)
        # New fc_in_size = 7 * 7 * 64 = 3136
        fc_in_size = 7*7*64

        self.fc = nn.Linear(fc_in_size, n_classes, bias=False)

    def forward(self, x):
        x = self.ConvBnRelu1(x)
        x = self.ConvBnRelu2(x)
        x = self.pool(x)
        x = self.ConvBnRelu3(x)
        x = self.dropout(x)
        x = x.flatten(1)
        output = self.fc(x)
        return output


net_reduced = CNN_reduced().to(device)

# %% [markdown]
# Let's see how many MAC operations the new network has...

# %%
params, macs = print_summary(deepcopy(net_reduced), input_size) #use deepcopy to avoid graph modifications by hese function calls
print("\nNetwork's \tn°params: %.3fk \tMAC: %.3fM\n" % (params/1e3, macs/1e6))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNN_reduced                              [1, 10]                   --
# ├─ConvBnRelu: 1-1                        [1, 16, 28, 28]           --
# │    └─Conv2d: 2-1                       [1, 16, 28, 28]           144
# │    └─BatchNorm2d: 2-2                  [1, 16, 28, 28]           32
# │    └─ReLU: 2-3                         [1, 16, 28, 28]           --
# ├─ConvBnRelu: 1-2                        [1, 32, 28, 28]           --
# │    └─Conv2d: 2-4                       [1, 32, 28, 28]           4,608
# │    └─BatchNorm2d: 2-5                  [1, 32, 28, 28]           64
# │    └─ReLU: 2-6                         [1, 32, 28, 28]           --
# ├─MaxPool2d: 1-3                         [1, 32, 14, 14]           --
# ├─ConvBnRelu: 1-4                        [1, 64, 7, 7]             --
# │    └─Conv2d: 2-7                       [1, 64, 7, 7]             18,432
# │    └─BatchNorm2d: 2-8                  [1, 64, 7, 7]             128
# │    └─ReLU: 2-9                         [1, 64, 7, 7]             --
# ├─Dropout: 1-5                           [1, 64, 7, 7]             --
# ├─Linear: 1-6                            [1, 10]                   31,360
# ==========================================================================================
# Total params: 54,768
# Trainable params: 54,768
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 4.66
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.65
# Params size (MB): 0.22
# Estimated Total Size (MB): 0.87
# ==========================================================================================
#
# Network's 	n°params: 54.768k 	MAC: 4.660M

# %% [markdown]
# **The New network has 4.66M MAC, which is less than our constrain of 5M !!**

# %% [markdown]
# # **TASK3:** Retrain the network and verify validation accuracy

# %% [markdown]
# You can use the same training loop you implemented in LAB2!

# %%
#@title Training parameters { form-width: "70%" }
epochs = 2 #@param {type:"integer"}
batch_size = 128 #@param {type:"integer"}

# %%
# Build Dataloaders
train_loader, val_loader = get_data_loaders(batch_size, batch_size)

# %%
# Train the network!
(train_loss_history,
train_accuracy_history,
val_loss_history,
val_accuracy_history) = training(net_reduced, train_loader, val_loader, loss_function, epochs)
# Out:
# Loss:   0%|          | 0/469 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 1/2 Training loss:  0.5132 Accuracy: 0.8193
# Validation Loss: 0.3586 Accuracy: 0.8730
# Loss:   0%|          | 0/469 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 2/2 Training loss:  0.3320 Accuracy: 0.8815
# Validation Loss: 0.3028 Accuracy: 0.8910
# Training time: 152.9 seconds

# %% [markdown]
# # **TASK4**: Quantization
#
# We want to quantize the network from a float32 representation to an _integer_ representation. As we studied in class, quantization is a technique that allow us to compress the neural network (i.e., reduce its size) and potentially to accelerate the inference time (float operations vs int operations). First, we'll use a "soft" technique called Post-Training Quantization to quantize our network _without_ retraining it.

# %% [markdown]
# We will use the open-source [**Brevitas**](https://github.com/Xilinx/brevitas) tool, developed by AMD Xilinx, as our main quantization framework. Resources:
#  * https://xilinx.github.io/brevitas/

# %% [markdown]
# The computational graph of our network uses floating-point operands, i.e., it is a floating-point computational graph.
#
# Similarly to other quantization tools, the first step of Brevitas' operation is to replace the nodes in the graph with ones that support quantization, i.e., explicitly include weight and (potentially) activation quantization in their `forward` methods.
# Quantization-aware nodes also make it possible to collect statistics on the weight and activation distribution, which on turn are usede to improve the quantization itself by selecting the correct quantization range.
# This information will be transformed into a set of floating-point zero-offsets and scaling factors applied to integer weights and activations.
#
# The conversion from a "pure" model to one that is quantization-aware is called the fake quantization, and it produces a **Fake-Quantized (FQ)** model: specifically the FQ step introduces linear quantizers into the computational graph, but at the same time continues to operate with floating-point operands.
# In Brevitas, fake quantization can be performed *layer-wise*, i.e., looking at one `torch.nn.Module` at a time, or referring to a `torch.fx` trace.
# The latter strategy is potentially more powerful for complex models, but also less simple to use: in this tutorial, we'll rely on the former one.
#
# The FQ graph is where we apply all transformation that still require complete trainability and, as a consequence, rely on float representation.
# However, the FQ graph cannot be directly deployed as it typically ignores some of the nodes (such as activations); scaling factors are applied in floating-point, which we generally want to avoid; and in general it is not a bit-true representation of any full-integer operation that will happen in deployment.
# We'll need a separate tool to perform a second-stage transformation to get to a fully integer graph.

# %% [markdown]
# ## **1st quantization step: Float-to-fake**
#
# This is the first step for preparing & converting a conventional neural network to the quantized form, which is where “fake quantization” nodes come in (image below: red nodes):
#
# * The role that fake quantization nodes fulfil is to simulate the rounding effect of quantization in the forward pass, as it would occur in actual inference of a quantized network. So we are not converting activation's output
# and the convolutional weights to fixed-point representation (`integer`), we are just adding a "fake quantization" node that simulates the effect of quantization. This allows to keep all parameters stored as float with the real full-precision.
#
# ***Why do we want to keep the original `float32` values?***
#
# * It is mandatory at training time, so that backpropagation still works as usual. A quantized network would have no way to be trained and updated with infinitesimal gradients.
#
# ***Why do we want to train a quantized network then ?***
#
# * Frequently, after applying quantization, we must run a few epochs of fine-tuning (called **quantization-aware training**) to adjust for the precision loss introduced by a lower bitwidth.
# * The alternative, which we'll follow in the first part of this tutorial, is to apply **post-training quantization**, which relies on statistics collection and calibration to adapt the ranges and scaling factors of quantizers.
#
# **Summary:** Fake quantization nodes simulates the quantization effects on weights and output activations just during the forward pass (`input->output`). While during backpropagation (`input<-output`) the fake quantization nodes are not active and the weights and activations retain their original `float32` values.

# %% [markdown]
# ![Figure2.png](data:image/png;base64,...)

# %% [markdown]
# To perform F2F conversion, we must replace standard PyTorch Modules with corresponding FakeQuantized counterparts.
# With Brevitas, we start by taking a "deep copy" of our initial floating-point net (to keep it untouched), then we operate on the copy.
#
# Our first step is to perform *activation equalization*, a technique based on [**SmoothQuant**](https://arxiv.org/abs/2211.10438) used to smooth out any outliers in the activation distribution by migrating their "quantization difficulty" towards weights.
# This is directly supported in Brevitas and can be run to our copied network as a preliminary step.
# Afterwards, we run one validation round to double-check functionality.

# %%
from copy import deepcopy

# DeepCopy of net + ugly bias workaround
net_copy = deepcopy(net)

for layer in [net_copy.ConvBnRelu1.conv1, net_copy.ConvBnRelu2.conv1, net_copy.ConvBnRelu3.conv1, net_copy.fc]:
    layer.bias = torch.nn.Parameter(torch.zeros(layer.weight.size()[0]))

# %%
from brevitas.graph.calibrate import bias_correction_mode, calibration_mode
from brevitas.graph.equalize import activation_equalization_mode

def equalize_activations(net, cal_loader, alpha=0.5):

    # set net to evaluating (testing)
    net.eval()
    with activation_equalization_mode(net, alpha):
      with torch.no_grad():
          for batch_idx, data in enumerate(cal_loader):
              inputs, _ = data[0].to(device), data[1].to(device)

              # net forward
              _ = net(inputs) # this gets the prediction from the network

# use validation set for activation equalization
calib_loader = val_loader
equalize_activations(net_copy, calib_loader)

average_val_accuracy, average_val_loss = validate(net_copy, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 0.2610 Accuracy: 0.9048

# %% [markdown]
# We expect the accuracy to be virtually unchanged compared to before equalization.
#
# After equalization, we can perform the actual network fake-quantization, which in Brevitas is done through the `quantize_model` API. Here we make several choices:
#  * the backend selected is `layerwise`. This is used to select whether `torch.nn.Module`s are being transformed one by one, or if the full graph produced by `torch.fx` is managed.
#  * we select the bit width for weights (8b), activation (8b), bias (32b).
#  * we select the granularity of weight quantization: `per_tensor` means that one single scaling factor (and a related range from `wmin` to `wmax`) is used for all the weights.
#  * `act_quant_percentile` is used in calibration: in this case, we select to keep activation up to the 99.999% percentile within the representable range. Reducing the range might make it easier to quantize, but will result in gross precision loss on activation outliers. We also select the `act_quant_type` as `sym`metric (i.e., representable data goes from -N to +N).
#  * as `scale_factor_type` we select `float_scale`, which means that quantization will be free to use any scaling factor. Conversely, we could also set up quantization to use only power-of-two scaling factors: this makes it possible to reduce all normalization to simple shifts (practically a regular fixed-point representation), at the price of losing flexibility, and thus accuracy.
#
# After this step, we perform another accuracy evaluation to check for functionality.

# %%
from brevitas.graph.quantize import preprocess_for_quantize
gnet = preprocess_for_quantize(net_copy)

average_val_accuracy, average_val_loss = validate(gnet, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 0.2610 Accuracy: 0.9048

# %% [markdown]
# ----
# **TASK ASSIGNMENT**
#
# Complete the Layer Map following the choices stated before.
#
# **Tip**: All classes you need are imported (you virtually do not need the documentation).

# %%
# from brevitas_examples.imagenet_classification.ptq.ptq_common import quantize_model
from brevitas.export.inference import quant_inference_mode
from brevitas.graph.quantize import quantize
from brevitas.quant import (
  Int8ActPerTensorFloat,
  Int8WeightPerTensorFloat,
  Int32Bias,
  Uint8ActPerTensorFloat,
)

computeLayerMap = {
  nn.Conv2d: (
    qnn.QuantConv2d,
    {
      "input_quant": Int8ActPerTensorFloat ,
      "weight_quant": Int8WeightPerTensorFloat ,
      "output_quant": Int8ActPerTensorFloat ,
      "bias_quant": Int32Bias ,
      "bias": True,
      "return_quant_tensor": True,
      "output_bit_width": 8 ,
      "weight_bit_width": 8 ,
    },
  ),
  nn.Linear: (
    qnn.QuantLinear,
    {
      "input_quant": Int8ActPerTensorFloat ,
      "weight_quant": Int8WeightPerTensorFloat ,
      "output_quant": Int8ActPerTensorFloat ,
      "bias_quant": Int32Bias,
      "bias": True,
      "return_quant_tensor": True,
      "output_bit_width": 8 ,
      "weight_bit_width": 8 ,
    },
  ),
  nn.BatchNorm2d: (
    qnn.BatchNorm2dToQuantScaleBias,
    {
      'weight_quant': Int8WeightPerTensorFloat ,
      'bias_quant': Int32Bias ,
      'return_quant_tensor': True
    }
  ),
}

quantActMap = {
  nn.ReLU: (
    qnn.QuantReLU,
    {
      "act_quant": Uint8ActPerTensorFloat,
      "return_quant_tensor": True,
      "bit_width": 8,
    },
  ),
}

quantIdentityMap = {
  "signed": (
    qnn.QuantIdentity,
    {
      "act_quant": Int8ActPerTensorFloat,
      "return_quant_tensor": True,
      "bit_width": 8,
    },
  ),
  "unsigned": (
    qnn.QuantIdentity,
    {
      "act_quant": Uint8ActPerTensorFloat,
      "return_quant_tensor": True,
      "bit_width": 8,
    },
  ),
}

qnet = quantize(
  graph_model=gnet,
  compute_layer_map=computeLayerMap,
  quant_act_map=quantActMap,
  quant_identity_map=quantIdentityMap,
)


# Test over validation dataset
loss_function=nn.CrossEntropyLoss()

average_val_accuracy, average_val_loss = validate(qnet, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 1.4844 Accuracy: 0.7535

# %% [markdown]
# Did you notice the accuracy drop? We should do something about it!
# But before that, let us check the topology of the network. Spoiler: it is very different!

# %%
qnet.print_readable()
# Out:
# class CNN(torch.nn.Module):
#     def forward(self, x):
#         # No stacktrace found for following nodes
#         x_quant = self.x_quant(x);  x = None
#         conv_bn_relu1_conv1_scale_weight = self.ConvBnRelu1.conv1.scale.weight
#         view = conv_bn_relu1_conv1_scale_weight.view([1, 1, 1, 1]);  conv_bn_relu1_conv1_scale_weight = None
#         mul = x_quant * view;  x_quant = view = None
#         conv_bn_relu1_conv1_layer = self.ConvBnRelu1.conv1.layer(mul);  mul = None
#         conv_bn_relu1_relu1 = self.ConvBnRelu1.relu1(conv_bn_relu1_conv1_layer);  conv_bn_relu1_conv1_layer = None
#         conv_bn_relu2_conv1_scale_weight = self.ConvBnRelu2.conv1.scale.weight
#         view_1 = conv_bn_relu2_conv1_scale_weight.view([1, 32, 1, 1]);  conv_bn_relu2_conv1_scale_weight = None
#         mul_1 = conv_bn_relu1_relu1 * view_1;  conv_bn_relu1_relu1 = view_1 = None
#         conv_bn_relu2_conv1_layer = self.ConvBnRelu2.conv1.layer(mul_1);  mul_1 = None
#         conv_bn_relu2_relu1 = self.ConvBnRelu2.relu1(conv_bn_relu2_conv1_layer);  conv_bn_relu2_conv1_layer = None
#         pool = self.pool(conv_bn_relu2_relu1);  conv_bn_relu2_relu1 = None
#         conv_bn_relu3_conv1_scale_weight = self.ConvBnRelu3.conv1.scale.weight
#         view_2 = conv_bn_relu3_conv1_scale_weight.view([1, 64, 1, 1]);  conv_bn_relu3_conv1_scale_weight = None
#         mul_2 = pool * view_2;  pool = view_2 = None
#         conv_bn_relu3_conv1_layer = self.ConvBnRelu3.conv1.layer(mul_2);  mul_2 = None
#         conv_bn_relu3_relu1 = self.ConvBnRelu3.relu1(conv_bn_relu3_conv1_layer);  conv_bn_relu3_conv1_layer = None
#         dropout = self.dropout(conv_bn_relu3_relu1);  conv_bn_relu3_relu1 = None
#         flatten = dropout.flatten(1);  dropout = None
#         fc_scale_weight = self.fc.scale.weight
#         view_3 = fc_scale_weight.view([1, 6272]);  fc_scale_weight = None
#         mul_3 = flatten * view_3;  flatten = view_3 = None
#         fc_layer = self.fc.layer(mul_3);  mul_3 = None
#         fc_layer_output_quant = self.fc_layer_output_quant(fc_layer);  fc_layer = None
#         return fc_layer_output_quant
# /usr/local/lib/python3.12/dist-packages/brevitas/backport/fx/experimental/proxy_tensor.py:97: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   pytree._register_pytree_node(torch.Size, lambda x: (list(x), None), lambda xs, _: tuple(xs))
# /usr/local/lib/python3.12/dist-packages/torch/utils/_pytree.py:332: UserWarning: <class 'torch.Size'> is already registered as pytree node. Overwriting the previous registration.
#   warnings.warn(
# 'class CNN(torch.nn.Module):\n    def forward(self, x):\n        # No stacktrace found for following nodes\n        x_quant = self.x_quant(x);  x = None\n        conv_bn_relu1_conv1_scale_weight = self.ConvBnRelu1.conv1.scale.weight\n        view = conv_bn_relu1_conv1_scale_weight.view([1, 1, 1, 1]);  conv_bn_relu1_conv1_scale_weight = None\n        mul = x_quant * view;  x_quant = view = None\n        conv_bn_relu1_conv1_layer = self.ConvBnRelu1.conv1.layer(mul);  mul = None\n        conv_bn_relu1_relu1 = self.ConvBnRelu1.relu1(conv_bn_relu1_conv1_layer);  conv_bn_relu1_conv1_layer = None\n        conv_bn_relu2_conv1_scale_weight = self.ConvBnRelu2.conv1.scale.weight\n        view_1 = conv_bn_relu2_conv1_scale_weight.view([1, 32, 1, 1]);  conv_bn_relu2_conv1_scale_weight = None\n        mul_1 = conv_bn_relu1_relu1 * view_1;  conv_bn_relu1_relu1 = view_1 = None\n        conv_bn_relu2_conv1_layer = self.ConvBnRelu2.conv1.layer(mul_1);  mul_1 = None\n        conv_bn_relu2_relu1 = self.ConvBnRelu2.relu1(conv_bn_relu2_conv1_layer);  conv_bn_relu2_conv1_layer = None\n        pool = self.pool(conv_bn_relu2_relu1);  conv_bn_relu2_relu1 = None\n        conv_bn_relu3_conv1_scale_weight = self.ConvBnRelu3.conv1.scale.weight\n        view_2 = conv_bn_relu3_conv1_scale_weight.view([1, 64, 1, 1]);  conv_bn_relu3_conv1_scale_weight = None\n        mul_2 = pool * view_2;  pool = view_2 = None\n        conv_bn_relu3_conv1_layer = self.ConvBnRelu3.conv1.layer(mul_2);  mul_2 = None\n        conv_bn_relu3_relu1 = self.ConvBnRelu3.relu1(conv_bn_relu3_conv1_layer);  conv_bn_relu3_conv1_layer = None\n        dropout = self.dropout(conv_bn_relu3_relu1);  conv_bn_relu3_relu1 = None\n        flatten = dropout.flatten(1);  dropout = None\n        fc_scale_weight = self.fc.scale.weight\n        view_3 = fc_scale_weight.view([1, 6272]);  fc_scale_weight = None\n        mul_3 = flatten * view_3;  flatten = view_3 = None\n        fc_layer = self.fc.layer(mul_3);  mul_3 = None\n        fc_layer_output_quant = self.fc_layer_output_quant(fc_layer);  fc_layer = None\n        return fc_layer_output_quant\n        '

# %% [markdown]
# To fix network accuracy, we need to initialize correctly the minima and maxima of activations, which is used to correctly represent them in the latter operations. This step is typically called calibration and, in PTQ, it is the only typically necessary step to achieve good performance. We expect virtually no accuracy loss compared to the floating-point network after calibration.

# %%
from brevitas_examples.imagenet_classification.ptq.ptq_common import calibrate

#FIXME move to with "explicit" form
calib_loader = val_loader
# initializes wmax,wmin, amax, amin
calibrate(calib_loader, qnet)

# Test over validation dataset
loss_function=nn.CrossEntropyLoss()
with torch.no_grad(), quant_inference_mode(qnet):
  average_val_accuracy, average_val_loss = validate(qnet, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
# 100%|██████████| 79/79 [00:39<00:00,  1.98it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 0.2610 Accuracy: 0.9046

# %% [markdown]
# At this stage, the FQ of the network is complete. Try to progressively reduce the target bitwidth to less than 8b for weights and activations: what happens? Also check what happens, particularly with low bitwidth, if you remove equalization or calibration. Finally, explore what happens if you replace the "original" model with the one you shrinked.
# Each time, start back from the equalization phase, where you copied `net` in `net_copy`.

# %% [markdown]
# ## **2nd quantization step: Quantization-aware training (QAT)**
#
# After applying quantization, we can run a few epochs  (just 1 enough in this case)  of fine-tuning, called *Quantization-Aware Training (QAT)*, to adjust for the precision loss introduced by a lower bitwidth.
# This is particularly useful if we target very low bitwidth networks.

# %% [markdown]
# Let's define the Quantization-Aware Training function:

# %%
#@title Number of quatization-aware training (QAT) epochs { form-width: "70%" }
n_QAT_epochs = 1 #@param {type:"integer"}

# %% [markdown]
# Start Quantization-aware fine-tuning !

# %%
# Train the network!
(train_loss_history,
train_accuracy_history,
val_loss_history,
val_accuracy_history) = training(qnet, train_loader, val_loader, loss_function, n_QAT_epochs, lr=1e-5)
# Out:
# Loss:   0%|          | 0/469 [00:00<?, ?it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Epoch 1/1 Training loss:  0.2239 Accuracy: 0.9194
# Validation Loss: 0.2451 Accuracy: 0.9127
# Training time: 370.7 seconds

# %%
from brevitas_examples.imagenet_classification.ptq.ptq_common import calibrate

#FIXME move to with "explicit" forma
calib_loader = val_loader
# initializes wmax,wmin, amax, amin
calibrate(calib_loader, qnet)

# Test over validation dataset
loss_function=nn.CrossEntropyLoss()
with torch.no_grad(), quant_inference_mode(qnet):
  average_val_accuracy, average_val_loss = validate(qnet, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('Validation Loss: %.4f' % (average_val_loss), 'Accuracy: %.4f' % (average_val_accuracy))
# Out:
# 100%|██████████| 79/79 [00:11<00:00,  7.11it/s]
#   0%|          | 0/79 [00:00<?, ?it/s]
# Validation Loss: 0.2451 Accuracy: 0.9127

# %% [markdown]
# ## **3rd quantization step: Fake-to-true**
#
# At this stage, we drop the "fake-quantization nodes" (the red nodes in the figure) and we transform all parameters to a fully integer representation, dropping the original `float32` values.
# For doing so, we must freeze the `min` and `max` range and the scaling factor for the input, also called *quantum*. This process is called **True Quantization (TQ)**.

# %% [markdown]
# ![immagine_2021-11-24_232846.png](data:image/png;base64,...)

# %% [markdown]
# We perform this transformation using **DeepQuant**, a PULP platform tool that is specialized in transforming the FQ output of Brevitas and bringing it to TQ.
# DeepQuant operates in a nearly automatic way.
# DeepQuant is in *alpha* stage: do not expect everything to work smoothly!

# %% [markdown]
# It can happen that you get an error at this stage: **don't panic** and rerun the cell. DeepQuant is designed to stop if outputs are not consistent, meaning the step has changed the output significantly.

# %%
#@title fake-to-true (F2T) function {form-width: "30%"}

from DeepQuant.DeepQuant import brevitasToTrueQuant # if you have trouble (unknown location), change to DeepQuant.DeepQuant
sampleInput = torch.randn(1, 1, 28, 28)
tqnet = brevitasToTrueQuant(qnet, sampleInput, exportPath="./DeepQuantTest", debug=True)
# Out:
# ==================================================
# 1. Original Network
# ==================================================
# ┍━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ opcode        │ class         │ name                             │ target                         │
# ┝━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ placeholder   │               │ x                                │ x                              │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantIdentity │ x_quant                          │ x_quant                        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ get_attr      │               │ conv_bn_relu1_conv1_scale_weight │ ConvBnRelu1.conv1.scale.weight │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_method   │               │ view                             │ view                           │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_function │               │ mul                              │ <built-in function mul>        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantConv2d   │ conv_bn_relu1_conv1_layer        │ ConvBnRelu1.conv1.layer        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantReLU     │ conv_bn_relu1_relu1              │ ConvBnRelu1.relu1              │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ get_attr      │               │ conv_bn_relu2_conv1_scale_weight │ ConvBnRelu2.conv1.scale.weight │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_method   │               │ view_1                           │ view                           │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_function │               │ mul_1                            │ <built-in function mul>        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantConv2d   │ conv_bn_relu2_conv1_layer        │ ConvBnRelu2.conv1.layer        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantReLU     │ conv_bn_relu2_relu1              │ ConvBnRelu2.relu1              │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ MaxPool2d     │ pool                             │ pool                           │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ get_attr      │               │ conv_bn_relu3_conv1_scale_weight │ ConvBnRelu3.conv1.scale.weight │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_method   │               │ view_2                           │ view                           │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_function │               │ mul_2                            │ <built-in function mul>        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantConv2d   │ conv_bn_relu3_conv1_layer        │ ConvBnRelu3.conv1.layer        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantReLU     │ conv_bn_relu3_relu1              │ ConvBnRelu3.relu1              │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ Dropout       │ dropout                          │ dropout                        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_method   │               │ flatten                          │ flatten                        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ get_attr      │               │ fc_scale_weight                  │ fc.scale.weight                │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_method   │               │ view_3                           │ view                           │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_function │               │ mul_3                            │ <built-in function mul>        │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantLinear   │ fc_layer                         │ fc.layer                       │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ call_module   │ QuantIdentity │ fc_layer_output_quant            │ fc_layer_output_quant          │
# ├───────────────┼───────────────┼──────────────────────────────────┼────────────────────────────────┤
# │ output        │               │ output                           │ output                         │
# ┕━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
#
#  ✓ LinearTransformation transformation successful
#     leafClasses: [<class 'DeepQuant.CustomForwards.WBIOL.WrapperWBIOL'>]
#     nonLeafClasses: [<class 'brevitas.nn.quant_layer.QuantWeightBiasInputOutputLayer'>]
#  ✓ ActivationTransformation transformation successful
#     leafClasses: [<class 'DeepQuant.CustomForwards.WBIOL.WrapperWBIOL'>, <class 'DeepQuant.CustomForwards.Activations.WrapperActivation'>]
#     nonLeafClasses: [<class 'brevitas.nn.quant_layer.QuantWeightBiasInputOutputLayer'>, <class 'brevitas.nn.quant_layer.QuantNonLinearActLayer'>]
#  ✓ Injection of New Modules: output is consistent
#
# ==================================================
# 2. Network after Injection of New Modules
# ==================================================
# ┍━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ opcode        │ class                        │ name                                                 │ target                                          │
# ┝━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ placeholder   │                              │ x                                                    │ x                                               │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ x_quant_input_quant                                  │ x_quant.input_quant                             │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation            │ x_quant_wrapped_act_impl                             │ x_quant.wrappedActImpl                          │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ x_quant_act_quant                                    │ x_quant.act_quant                               │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu1_conv1_scale_weight                     │ ConvBnRelu1.conv1.scale.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                              │ view                                                 │ view                                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                              │ mul                                                  │ <built-in function mul>                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu1_conv1_layer_input_quant                │ ConvBnRelu1.conv1.layer.input_quant             │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu1_conv1_layer_weight                     │ ConvBnRelu1.conv1.layer.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WeightQuantProxyFromInjector │ conv_bn_relu1_conv1_layer_weight_quant               │ ConvBnRelu1.conv1.layer.weight_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu1_conv1_layer_bias                       │ ConvBnRelu1.conv1.layer.bias                    │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ BiasQuantProxyFromInjector   │ conv_bn_relu1_conv1_layer_bias_quant                 │ ConvBnRelu1.conv1.layer.bias_quant              │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL                 │ conv_bn_relu1_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu1.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu1_conv1_layer_output_quant               │ ConvBnRelu1.conv1.layer.output_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu1_relu1_input_quant                      │ ConvBnRelu1.relu1.input_quant                   │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation            │ conv_bn_relu1_relu1_wrapped_act_impl                 │ ConvBnRelu1.relu1.wrappedActImpl                │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu1_relu1_act_quant                        │ ConvBnRelu1.relu1.act_quant                     │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu2_conv1_scale_weight                     │ ConvBnRelu2.conv1.scale.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                              │ view_1                                               │ view                                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                              │ mul_1                                                │ <built-in function mul>                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu2_conv1_layer_input_quant                │ ConvBnRelu2.conv1.layer.input_quant             │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu2_conv1_layer_weight                     │ ConvBnRelu2.conv1.layer.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WeightQuantProxyFromInjector │ conv_bn_relu2_conv1_layer_weight_quant               │ ConvBnRelu2.conv1.layer.weight_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu2_conv1_layer_bias                       │ ConvBnRelu2.conv1.layer.bias                    │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ BiasQuantProxyFromInjector   │ conv_bn_relu2_conv1_layer_bias_quant                 │ ConvBnRelu2.conv1.layer.bias_quant              │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL                 │ conv_bn_relu2_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu2.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu2_conv1_layer_output_quant               │ ConvBnRelu2.conv1.layer.output_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu2_relu1_input_quant                      │ ConvBnRelu2.relu1.input_quant                   │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation            │ conv_bn_relu2_relu1_wrapped_act_impl                 │ ConvBnRelu2.relu1.wrappedActImpl                │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu2_relu1_act_quant                        │ ConvBnRelu2.relu1.act_quant                     │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ MaxPool2d                    │ pool                                                 │ pool                                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu3_conv1_scale_weight                     │ ConvBnRelu3.conv1.scale.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                              │ view_2                                               │ view                                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                              │ mul_2                                                │ <built-in function mul>                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu3_conv1_layer_input_quant                │ ConvBnRelu3.conv1.layer.input_quant             │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu3_conv1_layer_weight                     │ ConvBnRelu3.conv1.layer.weight                  │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WeightQuantProxyFromInjector │ conv_bn_relu3_conv1_layer_weight_quant               │ ConvBnRelu3.conv1.layer.weight_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ conv_bn_relu3_conv1_layer_bias                       │ ConvBnRelu3.conv1.layer.bias                    │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ BiasQuantProxyFromInjector   │ conv_bn_relu3_conv1_layer_bias_quant                 │ ConvBnRelu3.conv1.layer.bias_quant              │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL                 │ conv_bn_relu3_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu3.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu3_conv1_layer_output_quant               │ ConvBnRelu3.conv1.layer.output_quant            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu3_relu1_input_quant                      │ ConvBnRelu3.relu1.input_quant                   │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation            │ conv_bn_relu3_relu1_wrapped_act_impl                 │ ConvBnRelu3.relu1.wrappedActImpl                │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ conv_bn_relu3_relu1_act_quant                        │ ConvBnRelu3.relu1.act_quant                     │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dropout                      │ dropout                                              │ dropout                                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                              │ flatten                                              │ flatten                                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ fc_scale_weight                                      │ fc.scale.weight                                 │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                              │ view_3                                               │ view                                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                              │ mul_3                                                │ <built-in function mul>                         │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ fc_layer_input_quant                                 │ fc.layer.input_quant                            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ fc_layer_weight                                      │ fc.layer.weight                                 │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WeightQuantProxyFromInjector │ fc_layer_weight_quant                                │ fc.layer.weight_quant                           │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                              │ fc_layer_bias                                        │ fc.layer.bias                                   │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ BiasQuantProxyFromInjector   │ fc_layer_bias_quant                                  │ fc.layer.bias_quant                             │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL                 │ fc_layer_wrapped_inner_forward_impl                  │ fc.layer.wrappedInnerForwardImpl                │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ fc_layer_output_quant                                │ fc.layer.output_quant                           │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ fc_layer_output_quant_input_quant                    │ fc_layer_output_quant.input_quant               │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation            │ fc_layer_output_quant_wrapped_act_impl               │ fc_layer_output_quant.wrappedActImpl            │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ ActQuantProxyFromInjector    │ fc_layer_output_quant_act_quant                      │ fc_layer_output_quant.act_quant                 │
# ├───────────────┼──────────────────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ output        │                              │ output                                               │ output                                          │
# ┕━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┷━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┙
#
# Extracted Parameters from the Network:
#   x_quant.input_quant:
#     scale: None
#     zero_point: None
#     bit_width: None
#     is_signed: None
#
#   x_quant.act_quant:
#     scale: 0.015798117965459824
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu1.conv1.layer.input_quant:
#     scale: 0.006748617626726627
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu1.conv1.layer.weight_quant:
#     scale: 0.040272001177072525
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu1.conv1.layer.bias_quant:
#     scale: 0.0002718329196795821
#     zero_point: 0.0
#     bit_width: 32.0
#     is_signed: True
#
#   ConvBnRelu1.conv1.layer.output_quant:
#     scale: 0.05963137745857239
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu1.relu1.input_quant:
#     scale: None
#     zero_point: None
#     bit_width: None
#     is_signed: None
#
#   ConvBnRelu1.relu1.act_quant:
#     scale: 0.02831789292395115
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: False
#
#   ConvBnRelu2.conv1.layer.input_quant:
#     scale: 0.00560830207541585
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu2.conv1.layer.weight_quant:
#     scale: 0.03375878930091858
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu2.conv1.layer.bias_quant:
#     scale: 0.00018926520715467632
#     zero_point: 0.0
#     bit_width: 32.0
#     is_signed: True
#
#   ConvBnRelu2.conv1.layer.output_quant:
#     scale: 0.06337273120880127
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu2.relu1.input_quant:
#     scale: None
#     zero_point: None
#     bit_width: None
#     is_signed: None
#
#   ConvBnRelu2.relu1.act_quant:
#     scale: 0.022738711908459663
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: False
#
#   ConvBnRelu3.conv1.layer.input_quant:
#     scale: 0.004748642444610596
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu3.conv1.layer.weight_quant:
#     scale: 0.01743859052658081
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu3.conv1.layer.bias_quant:
#     scale: 8.277250162791461e-05
#     zero_point: 0.0
#     bit_width: 32.0
#     is_signed: True
#
#   ConvBnRelu3.conv1.layer.output_quant:
#     scale: 0.05393290892243385
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   ConvBnRelu3.relu1.input_quant:
#     scale: None
#     zero_point: None
#     bit_width: None
#     is_signed: None
#
#   ConvBnRelu3.relu1.act_quant:
#     scale: 0.02512863278388977
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: False
#
#   fc.layer.input_quant:
#     scale: 0.003930583596229553
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   fc.layer.weight_quant:
#     scale: 0.0052388617768883705
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   fc.layer.bias_quant:
#     scale: 2.0627710910048336e-05
#     zero_point: 0.0
#     bit_width: 32.0
#     is_signed: True
#
#   fc.layer.output_quant:
#     scale: 0.15383782982826233
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#   fc_layer_output_quant.input_quant:
#     scale: None
#     zero_point: None
#     bit_width: None
#     is_signed: None
#
#   fc_layer_output_quant.act_quant:
#     scale: 0.1538713276386261
#     zero_point: 0.0
#     bit_width: 8.0
#     is_signed: True
#
#  › Starting Quantization Node Splitting...
#  › Quantization Node Splitting completed Successfully
#  ✓ Split of Quant Nodes: output is consistent
#
# ==================================================
# 3. Network after Split of Quant Nodes
# ==================================================
# ┍━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┯━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┑
# │ opcode        │ class             │ name                                                 │ target                                          │
# ┝━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┿━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┥
# │ placeholder   │                   │ x                                                    │ x                                               │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ x_input_quant_1                                      │ x_input_quant_1                                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ x_input_dequant                                      │ x_input_dequant                                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ x_wrapped_act_impl_quant_1                           │ x_wrappedActImpl_quant_1                        │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ x_wrapped_act_impl_dequant                           │ x_wrappedActImpl_dequant                        │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ x_act_quant_1                                        │ x_act_quant_1                                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ x_act_dequant                                        │ x_act_dequant                                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu1_conv1_scale_weight                     │ ConvBnRelu1.conv1.scale.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                   │ view                                                 │ view                                            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                   │ mul                                                  │ <built-in function mul>                         │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_conv1_layer_input_quant_1              │ ConvBnRelu1_conv1_layer_input_quant_1           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_conv1_layer_input_dequant              │ ConvBnRelu1_conv1_layer_input_dequant           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu1_conv1_layer_weight                     │ ConvBnRelu1.conv1.layer.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_conv1_layer_weight_quant_1             │ ConvBnRelu1_conv1_layer_weight_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_conv1_layer_weight_dequant             │ ConvBnRelu1_conv1_layer_weight_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu1_conv1_layer_bias                       │ ConvBnRelu1.conv1.layer.bias                    │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_conv1_layer_bias_quant_1               │ ConvBnRelu1_conv1_layer_bias_quant_1            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_conv1_layer_bias_dequant               │ ConvBnRelu1_conv1_layer_bias_dequant            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL      │ conv_bn_relu1_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu1.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_conv1_layer_output_quant_1             │ ConvBnRelu1_conv1_layer_output_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_conv1_layer_output_dequant             │ ConvBnRelu1_conv1_layer_output_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_relu1_input_quant_1                    │ ConvBnRelu1_relu1_input_quant_1                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_relu1_input_dequant                    │ ConvBnRelu1_relu1_input_dequant                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation │ conv_bn_relu1_relu1_wrapped_act_impl                 │ ConvBnRelu1.relu1.wrappedActImpl                │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu1_relu1_act_quant_1                      │ ConvBnRelu1_relu1_act_quant_1                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu1_relu1_act_dequant                      │ ConvBnRelu1_relu1_act_dequant                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu2_conv1_scale_weight                     │ ConvBnRelu2.conv1.scale.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                   │ view_1                                               │ view                                            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                   │ mul_1                                                │ <built-in function mul>                         │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_conv1_layer_input_quant_1              │ ConvBnRelu2_conv1_layer_input_quant_1           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_conv1_layer_input_dequant              │ ConvBnRelu2_conv1_layer_input_dequant           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu2_conv1_layer_weight                     │ ConvBnRelu2.conv1.layer.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_conv1_layer_weight_quant_1             │ ConvBnRelu2_conv1_layer_weight_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_conv1_layer_weight_dequant             │ ConvBnRelu2_conv1_layer_weight_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu2_conv1_layer_bias                       │ ConvBnRelu2.conv1.layer.bias                    │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_conv1_layer_bias_quant_1               │ ConvBnRelu2_conv1_layer_bias_quant_1            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_conv1_layer_bias_dequant               │ ConvBnRelu2_conv1_layer_bias_dequant            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL      │ conv_bn_relu2_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu2.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_conv1_layer_output_quant_1             │ ConvBnRelu2_conv1_layer_output_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_conv1_layer_output_dequant             │ ConvBnRelu2_conv1_layer_output_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_relu1_input_quant_1                    │ ConvBnRelu2_relu1_input_quant_1                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_relu1_input_dequant                    │ ConvBnRelu2_relu1_input_dequant                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation │ conv_bn_relu2_relu1_wrapped_act_impl                 │ ConvBnRelu2.relu1.wrappedActImpl                │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu2_relu1_act_quant_1                      │ ConvBnRelu2_relu1_act_quant_1                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu2_relu1_act_dequant                      │ ConvBnRelu2_relu1_act_dequant                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ MaxPool2d         │ pool                                                 │ pool                                            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu3_conv1_scale_weight                     │ ConvBnRelu3.conv1.scale.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_method   │                   │ view_2                                               │ view                                            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_function │                   │ mul_2                                                │ <built-in function mul>                         │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_conv1_layer_input_quant_1              │ ConvBnRelu3_conv1_layer_input_quant_1           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_conv1_layer_input_dequant              │ ConvBnRelu3_conv1_layer_input_dequant           │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu3_conv1_layer_weight                     │ ConvBnRelu3.conv1.layer.weight                  │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_conv1_layer_weight_quant_1             │ ConvBnRelu3_conv1_layer_weight_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_conv1_layer_weight_dequant             │ ConvBnRelu3_conv1_layer_weight_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ get_attr      │                   │ conv_bn_relu3_conv1_layer_bias                       │ ConvBnRelu3.conv1.layer.bias                    │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_conv1_layer_bias_quant_1               │ ConvBnRelu3_conv1_layer_bias_quant_1            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_conv1_layer_bias_dequant               │ ConvBnRelu3_conv1_layer_bias_dequant            │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperWBIOL      │ conv_bn_relu3_conv1_layer_wrapped_inner_forward_impl │ ConvBnRelu3.conv1.layer.wrappedInnerForwardImpl │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_conv1_layer_output_quant_1             │ ConvBnRelu3_conv1_layer_output_quant_1          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_conv1_layer_output_dequant             │ ConvBnRelu3_conv1_layer_output_dequant          │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_relu1_input_quant_1                    │ ConvBnRelu3_relu1_input_quant_1                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_relu1_input_dequant                    │ ConvBnRelu3_relu1_input_dequant                 │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ WrapperActivation │ conv_bn_relu3_relu1_wrapped_act_impl                 │ ConvBnRelu3.relu1.wrappedActImpl                │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Quant             │ conv_bn_relu3_relu1_act_quant_1                      │ ConvBnRelu3_relu1_act_quant_1                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# │ call_module   │ Dequant           │ conv_bn_relu3_relu1_act_dequant                      │ ConvBnRelu3_relu1_act_dequant                   │
# ├───────────────┼───────────────────┼──────────────────────────────────────────────────────┼─────────────────────────────────────────────────┤
# ...
#     Max diff: 0.05963182
#     Min diff: 0.05963135
#     Mean diff: 0.00022818
#     Total differing values: 96 of 25088 (0.3827%)
#     Most common differences (up to 5):
#     · Δ=0.059631  (71 values) e.g. idx 494: 2.802675 → 2.862306
#     · Δ=0.059631  (12 values) e.g. idx 259: -0.536682 → -0.596314
#     · Δ=0.059631  (6 values) e.g. idx 604: 1.252259 → 1.311890
#     · Δ=0.059632  (3 values) e.g. idx 6996: -2.146729 → -2.206361
#     · Δ=0.059631  (2 values) e.g. idx 4079: -0.357788 → -0.417420
#   [DIFF] ConvBnRelu1_relu1_input_quant_1 | shape (1, 32, 28, 28)
#     Max diff: 0.05963182
#     Min diff: 0.05963135
#     Mean diff: 0.00022818
#     Total differing values: 96 of 25088 (0.3827%)
#     Most common differences (up to 5):
#     · Δ=0.059631  (71 values) e.g. idx 494: 2.802675 → 2.862306
#     · Δ=0.059631  (12 values) e.g. idx 259: -0.536682 → -0.596314
#     · Δ=0.059631  (6 values) e.g. idx 604: 1.252259 → 1.311890
#     · Δ=0.059632  (3 values) e.g. idx 6996: -2.146729 → -2.206361
#     · Δ=0.059631  (2 values) e.g. idx 4079: -0.357788 → -0.417420
#   [DIFF] ConvBnRelu1_relu1_input_dequant | shape (1, 32, 28, 28)
#     Max diff: 0.05963182
#     Min diff: 0.05963135
#     Mean diff: 0.00022818
#     Total differing values: 96 of 25088 (0.3827%)
#     Most common differences (up to 5):
#     · Δ=0.059631  (71 values) e.g. idx 494: 2.802675 → 2.862306
#     · Δ=0.059631  (12 values) e.g. idx 259: -0.536682 → -0.596314
#     · Δ=0.059631  (6 values) e.g. idx 604: 1.252259 → 1.311890
#     · Δ=0.059632  (3 values) e.g. idx 6996: -2.146729 → -2.206361
#     · Δ=0.059631  (2 values) e.g. idx 4079: -0.357788 → -0.417420
#   [DIFF] ConvBnRelu1.relu1.wrappedActImpl.actImpl | shape (1, 32, 28, 28)
#     Max diff: 0.05963182
#     Min diff: 0.05963135
#     Mean diff: 0.00022818
#     Total differing values: 96 of 25088 (0.3827%)
#     Most common differences (up to 5):
#     · Δ=0.059631  (71 values) e.g. idx 494: 2.802675 → 2.862306
#     · Δ=0.059631  (12 values) e.g. idx 259: -0.536682 → -0.596314
#     · Δ=0.059631  (6 values) e.g. idx 604: 1.252259 → 1.311890
#     · Δ=0.059632  (3 values) e.g. idx 6996: -2.146729 → -2.206361
#     · Δ=0.059631  (2 values) e.g. idx 4079: -0.357788 → -0.417420
#   [DIFF] ConvBnRelu1.relu1.wrappedActImpl | shape (1, 32, 28, 28)
#     Max diff: 0.05963182
#     Min diff: 0.05963135
#     Mean diff: 0.00022818
#     Total differing values: 96 of 25088 (0.3827%)
#     Most common differences (up to 5):
#     · Δ=0.059631  (71 values) e.g. idx 494: 2.802675 → 2.862306
#     · Δ=0.059631  (12 values) e.g. idx 259: -0.536682 → -0.596314
#     · Δ=0.059631  (6 values) e.g. idx 604: 1.252259 → 1.311890
#     · Δ=0.059632  (3 values) e.g. idx 6996: -2.146729 → -2.206361
#     · Δ=0.059631  (2 values) e.g. idx 4079: -0.357788 → -0.417420
#   [DIFF] ConvBnRelu1_relu1_act_quant_1 | shape (1, 32, 28, 28)
#     Max diff: 3.00000000
#     Min diff: 2.00000000
#     Mean diff: 0.00402583
#     Total differing values: 48 of 25088 (0.1913%)
#     Most common differences (up to 5):
#     · Δ=2.000000  (43 values) e.g. idx 494: 99.000000 → 101.000000
#     · Δ=3.000000  (5 values) e.g. idx 614: 29.000000 → 32.000000
#   [DIFF] ConvBnRelu1_relu1_act_dequant | shape (1, 32, 28, 28)
#     Max diff: 0.08495378
#     Min diff: 0.05663562
#     Mean diff: 0.00011400
#     Total differing values: 48 of 25088 (0.1913%)
#     Most common differences (up to 5):
#     · Δ=0.056636  (22 values) e.g. idx 494: 2.803471 → 2.860107
#     · Δ=0.056636  (10 values) e.g. idx 2364: 0.538040 → 0.594676
#     · Δ=0.056636  (9 values) e.g. idx 604: 1.245987 → 1.302623
#     · Δ=0.084954  (2 values) e.g. idx 614: 0.821219 → 0.906173
#     · Δ=0.084954  (2 values) e.g. idx 18010: 3.030015 → 3.114968
#   [DIFF] ConvBnRelu2_conv1_layer_input_quant_1 | shape (1, 32, 28, 28)
#     Max diff: 2.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.00243144
#     Total differing values: 48 of 25088 (0.1913%)
#     Most common differences (up to 5):
#     · Δ=1.000000  (35 values) e.g. idx 604: 31.000000 → 32.000000
#     · Δ=2.000000  (13 values) e.g. idx 494: 69.000000 → 71.000000
#   [OK] ConvBnRelu2_conv1_layer_input_dequant | shape (1, 32, 28, 28)
#   [OK] ConvBnRelu2_conv1_layer_weight_quant_1 | shape (64, 32, 3, 3)
#   [OK] ConvBnRelu2_conv1_layer_weight_dequant | shape (64, 32, 3, 3)
#   [OK] ConvBnRelu2_conv1_layer_bias_quant_1 | shape (64,)
#   [OK] ConvBnRelu2_conv1_layer_bias_dequant | shape (64,)
#   [DIFF] ConvBnRelu2.conv1.layer.wrappedInnerForwardImpl → ConvBnRelu2_conv1_layer_unified_dequant | shape (1, 64, 28, 28)
#     Max diff: 0.04135084
#     Min diff: 0.00000003
#     Mean diff: 0.00238973
#     Total differing values: 50176 of 50176 (100.0000%)
#     Most common differences (up to 5):
#     · Δ=0.000848  (12 values) e.g. idx 1257: 0.646431 → 0.645584
#     · Δ=0.000805  (11 values) e.g. idx 12296: 2.575758 → 2.574953
#     · Δ=0.000567  (10 values) e.g. idx 8: -1.293816 → -1.293249
#     · Δ=0.000632  (10 values) e.g. idx 6286: 1.260760 → 1.260128
#     · Δ=0.000270  (10 values) e.g. idx 968: -1.056398 → -1.056668
#   [DIFF] ConvBnRelu2_conv1_layer_output_quant_1 | shape (1, 64, 28, 28)
#     Max diff: 1.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.03698980
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=1.000000  (1856 values) e.g. idx 4: 40.000000 → 39.000000
#   [DIFF] ConvBnRelu2_conv1_layer_output_dequant | shape (1, 64, 28, 28)
#     Max diff: 0.06337309
#     Min diff: 0.06337261
#     Mean diff: 0.00234414
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=0.063373  (1272 values) e.g. idx 5: -0.443609 → -0.380236
#     · Δ=0.063373  (310 values) e.g. idx 4: 2.534909 → 2.471537
#     · Δ=0.063373  (240 values) e.g. idx 117: -2.408164 → -2.471537
#     · Δ=0.063373  (34 values) e.g. idx 6675: 4.436091 → 4.372718
#   [DIFF] ConvBnRelu2_relu1_input_quant_1 | shape (1, 64, 28, 28)
#     Max diff: 0.06337309
#     Min diff: 0.06337261
#     Mean diff: 0.00234414
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=0.063373  (1272 values) e.g. idx 5: -0.443609 → -0.380236
#     · Δ=0.063373  (310 values) e.g. idx 4: 2.534909 → 2.471537
#     · Δ=0.063373  (240 values) e.g. idx 117: -2.408164 → -2.471537
#     · Δ=0.063373  (34 values) e.g. idx 6675: 4.436091 → 4.372718
#   [DIFF] ConvBnRelu2_relu1_input_dequant | shape (1, 64, 28, 28)
#     Max diff: 0.06337309
#     Min diff: 0.06337261
#     Mean diff: 0.00234414
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=0.063373  (1272 values) e.g. idx 5: -0.443609 → -0.380236
#     · Δ=0.063373  (310 values) e.g. idx 4: 2.534909 → 2.471537
#     · Δ=0.063373  (240 values) e.g. idx 117: -2.408164 → -2.471537
#     · Δ=0.063373  (34 values) e.g. idx 6675: 4.436091 → 4.372718
#   [DIFF] ConvBnRelu2.relu1.wrappedActImpl.actImpl | shape (1, 64, 28, 28)
#     Max diff: 0.06337309
#     Min diff: 0.06337261
#     Mean diff: 0.00234414
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=0.063373  (1272 values) e.g. idx 5: -0.443609 → -0.380236
#     · Δ=0.063373  (310 values) e.g. idx 4: 2.534909 → 2.471537
#     · Δ=0.063373  (240 values) e.g. idx 117: -2.408164 → -2.471537
#     · Δ=0.063373  (34 values) e.g. idx 6675: 4.436091 → 4.372718
#   [DIFF] ConvBnRelu2.relu1.wrappedActImpl | shape (1, 64, 28, 28)
#     Max diff: 0.06337309
#     Min diff: 0.06337261
#     Mean diff: 0.00234414
#     Total differing values: 1856 of 50176 (3.6990%)
#     Most common differences (up to 5):
#     · Δ=0.063373  (1272 values) e.g. idx 5: -0.443609 → -0.380236
#     · Δ=0.063373  (310 values) e.g. idx 4: 2.534909 → 2.471537
#     · Δ=0.063373  (240 values) e.g. idx 117: -2.408164 → -2.471537
#     · Δ=0.063373  (34 values) e.g. idx 6675: 4.436091 → 4.372718
#   [DIFF] ConvBnRelu2_relu1_act_quant_1 | shape (1, 64, 28, 28)
#     Max diff: 3.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.04031808
#     Total differing values: 722 of 50176 (1.4389%)
#     Most common differences (up to 5):
#     · Δ=3.000000  (580 values) e.g. idx 61: 42.000000 → 39.000000
#     · Δ=2.000000  (141 values) e.g. idx 4: 111.000000 → 109.000000
#     · Δ=1.000000  (1 values) e.g. idx 9291: 254.000000 → 255.000000
#   [DIFF] ConvBnRelu2_relu1_act_dequant | shape (1, 64, 28, 28)
#     Max diff: 0.06821632
#     Min diff: 0.02273846
#     Mean diff: 0.00091678
#     Total differing values: 722 of 50176 (1.4389%)
#     Most common differences (up to 5):
#     · Δ=0.068216  (220 values) e.g. idx 175: 1.205152 → 1.136936
#     · Δ=0.068216  (176 values) e.g. idx 61: 0.955026 → 0.886810
#     · Δ=0.045477  (64 values) e.g. idx 4: 2.523997 → 2.478520
#     · Δ=0.068216  (53 values) e.g. idx 2646: 0.068216 → 0.136432
#     · Δ=0.045477  (47 values) e.g. idx 625: 0.136432 → 0.181910
#   [DIFF] ConvBnRelu3_conv1_layer_input_quant_1 | shape (1, 64, 14, 14)
#     Max diff: 3.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.04097576
#     Total differing values: 369 of 12544 (2.9416%)
#     Most common differences (up to 5):
#     · Δ=1.000000  (226 values) e.g. idx 2: 47.000000 → 46.000000
#     · Δ=2.000000  (141 values) e.g. idx 45: 23.000000 → 21.000000
#     · Δ=3.000000  (2 values) e.g. idx 1244: 20.000000 → 17.000000
#   [OK] ConvBnRelu3_conv1_layer_input_dequant | shape (1, 64, 14, 14)
#   [OK] ConvBnRelu3_conv1_layer_weight_quant_1 | shape (128, 64, 3, 3)
#   [OK] ConvBnRelu3_conv1_layer_weight_dequant | shape (128, 64, 3, 3)
#   [OK] ConvBnRelu3_conv1_layer_bias_quant_1 | shape (128,)
#   [OK] ConvBnRelu3_conv1_layer_bias_dequant | shape (128,)
#   [DIFF] ConvBnRelu3.conv1.layer.wrappedInnerForwardImpl → ConvBnRelu3_conv1_layer_unified_dequant | shape (1, 128, 7, 7)
#     Max diff: 0.09548813
#     Min diff: 0.00000103
#     Mean diff: 0.01128425
#     Total differing values: 6272 of 6272 (100.0000%)
#     Most common differences (up to 5):
#     · Δ=0.006813  (3 values) e.g. idx 2525: 1.447386 → 1.440573
#     · Δ=0.007236  (2 values) e.g. idx 5052: 2.745364 → 2.752599
#     · Δ=0.001220  (2 values) e.g. idx 613: 3.863428 → 3.864648
#     · Δ=0.012518  (2 values) e.g. idx 2762: -1.549316 → -1.561834
#     · Δ=0.000671  (2 values) e.g. idx 1421: -0.501096 → -0.501767
#   [DIFF] ConvBnRelu3_conv1_layer_output_quant_1 | shape (1, 128, 7, 7)
#     Max diff: 2.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.21029975
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=1.000000  (1315 values) e.g. idx 4: -80.000000 → -79.000000
#     · Δ=2.000000  (2 values) e.g. idx 3821: 43.000000 → 45.000000
#   [DIFF] ConvBnRelu3_conv1_layer_output_dequant | shape (1, 128, 7, 7)
#     Max diff: 0.10786583
#     Min diff: 0.05393267
#     Mean diff: 0.01134208
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=0.053933  (1043 values) e.g. idx 13: -1.671920 → -1.725853
#     · Δ=0.053933  (61 values) e.g. idx 9: -4.800029 → -4.746096
#     · Δ=0.053933  (58 values) e.g. idx 4: -4.314633 → -4.260700
#     · Δ=0.053933  (35 values) e.g. idx 136: -0.107866 → -0.053933
#     · Δ=0.053933  (32 values) e.g. idx 134: 0.539329 → 0.485396
#   [DIFF] ConvBnRelu3_relu1_input_quant_1 | shape (1, 128, 7, 7)
#     Max diff: 0.10786583
#     Min diff: 0.05393267
#     Mean diff: 0.01134208
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=0.053933  (1043 values) e.g. idx 13: -1.671920 → -1.725853
#     · Δ=0.053933  (61 values) e.g. idx 9: -4.800029 → -4.746096
#     · Δ=0.053933  (58 values) e.g. idx 4: -4.314633 → -4.260700
#     · Δ=0.053933  (35 values) e.g. idx 136: -0.107866 → -0.053933
#     · Δ=0.053933  (32 values) e.g. idx 134: 0.539329 → 0.485396
#   [DIFF] ConvBnRelu3_relu1_input_dequant | shape (1, 128, 7, 7)
#     Max diff: 0.10786583
#     Min diff: 0.05393267
#     Mean diff: 0.01134208
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=0.053933  (1043 values) e.g. idx 13: -1.671920 → -1.725853
#     · Δ=0.053933  (61 values) e.g. idx 9: -4.800029 → -4.746096
#     · Δ=0.053933  (58 values) e.g. idx 4: -4.314633 → -4.260700
#     · Δ=0.053933  (35 values) e.g. idx 136: -0.107866 → -0.053933
#     · Δ=0.053933  (32 values) e.g. idx 134: 0.539329 → 0.485396
#   [DIFF] ConvBnRelu3.relu1.wrappedActImpl.actImpl | shape (1, 128, 7, 7)
#     Max diff: 0.10786583
#     Min diff: 0.05393267
#     Mean diff: 0.01134208
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=0.053933  (1043 values) e.g. idx 13: -1.671920 → -1.725853
#     · Δ=0.053933  (61 values) e.g. idx 9: -4.800029 → -4.746096
#     · Δ=0.053933  (58 values) e.g. idx 4: -4.314633 → -4.260700
#     · Δ=0.053933  (35 values) e.g. idx 136: -0.107866 → -0.053933
#     · Δ=0.053933  (32 values) e.g. idx 134: 0.539329 → 0.485396
#   [DIFF] ConvBnRelu3.relu1.wrappedActImpl | shape (1, 128, 7, 7)
#     Max diff: 0.10786583
#     Min diff: 0.05393267
#     Mean diff: 0.01134208
#     Total differing values: 1317 of 6272 (20.9981%)
#     Most common differences (up to 5):
#     · Δ=0.053933  (1043 values) e.g. idx 13: -1.671920 → -1.725853
#     · Δ=0.053933  (61 values) e.g. idx 9: -4.800029 → -4.746096
#     · Δ=0.053933  (58 values) e.g. idx 4: -4.314633 → -4.260700
#     · Δ=0.053933  (35 values) e.g. idx 136: -0.107866 → -0.053933
#     · Δ=0.053933  (32 values) e.g. idx 134: 0.539329 → 0.485396
#   [DIFF] ConvBnRelu3_relu1_act_quant_1 | shape (1, 128, 7, 7)
#     Max diff: 5.00000000
#     Min diff: 2.00000000
#     Mean diff: 0.19212373
#     Total differing values: 569 of 6272 (9.0721%)
#     Most common differences (up to 5):
#     · Δ=2.000000  (504 values) e.g. idx 41: 28.000000 → 26.000000
#     · Δ=3.000000  (64 values) e.g. idx 96: 97.000000 → 94.000000
#     · Δ=5.000000  (1 values) e.g. idx 3821: 92.000000 → 97.000000
#   [DIFF] ConvBnRelu3_relu1_act_dequant | shape (1, 128, 7, 7)
#     Max diff: 0.12564301
#     Min diff: 0.05025721
#     Mean diff: 0.00482781
#     Total differing values: 569 of 6272 (9.0721%)
#     Most common differences (up to 5):
#     · Δ=0.050257  (211 values) e.g. idx 53: 2.814407 → 2.864664
#     · Δ=0.050257  (167 values) e.g. idx 41: 0.703602 → 0.653344
#     · Δ=0.050257  (73 values) e.g. idx 60: 1.733876 → 1.784133
#     · Δ=0.050257  (40 values) e.g. idx 70: 2.739021 → 2.688764
#     · Δ=0.075386  (26 values) e.g. idx 527: 0.980017 → 0.904631
#   [DIFF] fc_layer_input_quant_1 | shape (1, 6272)
#     Max diff: 3.00000000
#     Min diff: 1.00000000
#     Mean diff: 0.09646046
#     Total differing values: 512 of 6272 (8.1633%)
#     Most common differences (up to 5):
#     · Δ=1.000000  (420 values) e.g. idx 41: 14.000000 → 13.000000
#     · Δ=2.000000  (91 values) e.g. idx 56: 119.000000 → 117.000000
#     · Δ=3.000000  (1 values) e.g. idx 3374: 4.000000 → 7.000000
#   [OK] fc_layer_input_dequant | shape (1, 6272)
#   [OK] fc_layer_weight_quant_1 | shape (10, 6272)
#   [OK] fc_layer_weight_dequant | shape (10, 6272)
#   [OK] fc_layer_bias_quant_1 | shape (10,)
#   [OK] fc_layer_bias_dequant | shape (10,)
#   [DIFF] fc.layer.wrappedInnerForwardImpl → fc_layer_unified_dequant | shape (1, 10)
#     Max diff: 0.04146767
#     Min diff: 0.00416803
#     Mean diff: 0.02052987
#     Total differing values: 10 of 10 (100.0000%)
#     Most common differences (up to 5):
#     · Δ=0.004168  (1 values) e.g. idx 6: -5.109359 → -5.113527
#     · Δ=0.005518  (1 values) e.g. idx 4: -17.559473 → -17.564991
#     · Δ=0.011229  (1 values) e.g. idx 5: -19.576138 → -19.564909
#     · Δ=0.014490  (1 values) e.g. idx 1: -20.424065 → -20.438555
#     · Δ=0.020807  (1 values) e.g. idx 8: -2.283440 → -2.262633
#   [OK] fc_layer_output_quant_1 | shape (1, 10)
#   [OK] fc_layer_output_dequant | shape (1, 10)
#   [OK] fc_layer_output_input_quant_1 | shape (1, 10)
#   [OK] fc_layer_output_input_dequant | shape (1, 10)
#   [OK] fc_layer_output_wrappedActImpl_quant_1 | shape (1, 10)
#   [OK] fc_layer_output_wrappedActImpl_dequant | shape (1, 10)
#   [OK] fc_layer_output_act_quant_1 | shape (1, 10)
#   [OK] fc_layer_output_act_dequant | shape (1, 10)
#
#  ✓ Input data saved to DeepQuantTest/inputs.npz
#  ✓ Output data saved to DeepQuantTest/outputs.npz

# %% [markdown]
# A sanity check: we compare the predictions of the fully-integerised program with the ground truth to verify that they are coherent.

# %%
#@title Sanity check {form-width: "30%"}
import random
random_idx = random.randrange(0, len(val_loader.dataset))
# pick random image from dataset
x, y_gt_int = val_loader.dataset.__getitem__(random_idx)
x = x.unsqueeze(0)
net.to('cpu')
# prediction original float32 network
y_pr_float = net(x)
y_pr_float_max = y_pr_float.argmax(axis=1)

x, y_gt_int = val_loader.dataset.__getitem__(random_idx)
x = x.unsqueeze(0)
# prediction quantized network
y_pr = tqnet(x)
y_pr_int = y_pr.argmax(axis=1)

print("True Quantized: \t\tTrue: {} - Predicted: {}".format(int(y_gt_int), y_pr_int.item()))
print("FLOAT32:\tTrue: {} - Predicted: {}\n".format(int(y_gt_int), y_pr_float_max.item()))
# Out:
# True Quantized: 		True: 8 - Predicted: 8
# FLOAT32:	True: 8 - Predicted: 8

# %% [markdown]
# let's verify that the accuracy didn't drop between FLOAT32 and TrueQuantized stages.

# %%
# Test the NON QUANTIZED network over validation dataset
average_val_accuracy, average_val_loss = validate(net, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('FLOAT32 Validation Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# FLOAT32 Validation Accuracy: 0.9048

# %%
# Test the QUANTIZED network over validation dataset
average_val_accuracy, average_val_loss = validate(tqnet, val_loader, loss_function, accuracy_score)
# Print valid statistics
print('INT Validation Accuracy: %.4f' % (average_val_accuracy))
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# INT Validation Accuracy: 0.9130

# %% [markdown]
# # **Task5:** Export to ONNX format

# %% [markdown]
# The trained networks can be exported in [**ONNX (*Open Neural Network eXchange*)**)](https://github.com/onnx/onnx) format for  deployment tools. This format is recognized as the official format to export a deep neural network. This format stores all the necessary elements to reload a network:
# * topology: number of layers, how they are linked and their type;
# * layer structure: stride, filter dimension, channels, etc..
# * parameters: for each layer, all the weights and numeric parameters are stored.
#
# **How to use:** To see how the model looks like, the following cells will
# 1) trigger a download to your local machine, and 2)  open a frame into Colab to a tool called [Netron](https://netron.app). This tool that can be used to visualize it: just drag the ONNX file and drop it on top of the Netron frame!
#
#
# **IMPORTANT:** now we are going to visualize two networks: 1. the original float32 network (so, the non-quantized one), and 2) the quantized one.

# %% [markdown]
# ### **1. Export the original Float32 model (non-quantized!)**

# %% [markdown]
# Export the ONNX file of the NON-quantized network.

# %%
net.eval()
torch.onnx.export(net, input, 'ExampleNet_Float32.onnx')

# %% [markdown]
# Download the ONNX file on your local computer

# %%
from google.colab import files
files.download('ExampleNet_Float32.onnx')

# %% [markdown]
# Open Netron and visualize the non-quantized network, named: `ExampleNet_Float32`, by loading it to Netron.
# That is, accept cookies, and "open model" by dragging and dropping the file you downloaded.

# %%
#@title Open Netron {form-width: "30%"}
import urllib
from IPython.display import IFrame
url = urllib.parse.quote("https://netron.app/", safe=':/?=&')
IFrame(url, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://netron.app/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
# **ASSIGNMENT TASK:**
#
# Use Netron to analyze the ONNX file of the original NON QUANTIZED network and answer the following question:
#
# * What's the data format of the convolutional layers' weights? **Answer:** *The data format is 64,32,3,3 .*
#
# * Is the decimal part of the convolutional weights !=0 ?  Paste here the value of a single weight as an example. **Answer:** *Yes, the decimal part of the convolutional weights is not equal to zero. Example Weight Value: 0.482528954744339 (taken from the onnx::Conv_34 Initializer data).*
#
# * What's the kernel size of all the convolutions? **Answer:** *The kernel size of all the convolutional layers is 3 x 3.*
#
# ---

# %% [markdown]
# ***Hints:***
# - Examples of possible data formats: `int8`, `int16`, `int32`, `int64`, `float16`, `float32`
# - The decimal part of `1234.567` is `567`

# %% [markdown]
# ### **2. Study the Quantized model**

# %% [markdown]
# Open Netron and visualize the quantized network, named: `DeepQuantTest/network.onnx`

# %%
from google.colab import files
files.download('DeepQuantTest/network.onnx')

# %%
#@title Open Netron {form-width: "30%"}

import urllib
from IPython.display import IFrame
url = urllib.parse.quote("https://netron.app/", safe=':/?=&')
IFrame(url, width=800, height=600) # you can resize the Netron frame size here!
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://netron.app/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
# **ASSIGNMENT TASK:**
#
# Use Netron to analyze the ONNX file of the QUANTIZED network and answer the following question:
#
# * What's the size of the input image? **Answer:** *The size of the input image is 1 x 1 x 28 x 28*
# * What's the data format of all the convolutional weights? **Answer:** *32,1,3,3*
# * Is the decimal part of the convolutional weights !=0? **Tip**: You cannot see the values of weights, differently from the other ONNX file. Reason on the sequence of operations. **Answer:** *The decimal part of the convolutional weights is 0 because they are int8 quantized (range [–128, 127]) after rounding.*
# This is confirmed by the METRICS showing std = 0, meaning all weights are integer values with no decimals.
# * What's the kernel size of all the convolutions? **Answer:** *3 x 3*
# * What's the quantization bitwidth of the convolutional weights? **Tip**: look at the min/max values on the clip operation! **Answer:** *since min = -128 and max = 127 , it exactly matches the 8-bit signed integers. So the quantization bitwidth of the convolutional weights is 8 bits.*
#
#
# ---
